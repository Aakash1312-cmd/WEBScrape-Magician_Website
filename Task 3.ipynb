# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
# I HAVE CONVERTED THE DATA FROM A BOOK WEBSITE TO A CSV FILE

# %%
books = []
    
for i in range(1,5):
    url= f"https://books.toscrape.com/catalogue/page-{i}.html"
    response = requests.get(url)
    response = response.content
    soup = BeautifulSoup(response, 'html.parser')
    ol = soup.find('ol')
    articles = ol.find_all('article', class_='product_pod')
    


for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    star = article.find('p')
    star = star['class'][1]
    price = article.find('p',class_='price_color').text
    price = float(price[1:])
    books.append([title, price, star])

# %%
df = pd.DataFrame(books, columns=['Title', 'Price', 'Star Rating'])

# %%
df.to_csv('books.csv')

# %%
df = pd.read_csv('books.csv')
df
# Out:
#     Unnamed: 0                                              Title  Price  \
# 0            0           The Nameless City (The Nameless City #1)  38.16
# 1            1  The Murder That Never Was (Forensic Instincts #5)  54.11
# 2            2  The Most Perfect Thing: Inside (and Outside) a...  42.96
# 3            3  The Mindfulness and Acceptance Workbook for An...  23.89
# 4            4  The Life-Changing Magic of Tidying Up: The Jap...  16.77
# 5            5  The Inefficiency Assassin: Time Management Tac...  20.59
# 6            6  The Gutsy Girl: Escapades for Your Life of Epi...  37.13
# 7            7  The Electric Pencil: Drawings from Inside Stat...  56.06
# 8            8       The Death of Humanity: and the Case for Life  58.11
# 9            9  The Bulletproof Diet: Lose up to a Pound a Day...  49.05
# 10          10                                     The Art Forger  40.76
# 11          11  The Age of Genius: The Seventeenth Century and...  19.73
# 12          12  The Activist's Tao Te Ching: Ancient Advice fo...  32.24
# 13          13  Spark Joy: An Illustrated Master Class on the ...  41.83
# 14          14                                        Soul Reader  39.58
# 15          15                                           Security  39.25
# 16          16      Saga, Volume 6 (Saga (Collected Editions) #6)  25.02
# 17          17      Saga, Volume 5 (Saga (Collected Editions) #5)  51.04
# 18          18  Reskilling America: Learning to Labor in the T...  19.83
# 19          19  Rat Queens, Vol. 3: Demons (Rat Queens (Collec...  50.40
#
#    Star Rating
# 0         Four
# 1        Three
# 2         Four
# 3         Four
# 4        Three
# 5         Five
# 6          One
# 7          One
# 8         Four
# 9        Three
# 10       Three
# 11         One
# 12        Five
# 13        Four
# 14         Two
# 15         Two
# 16       Three
# 17         Two
# 18         Two
# 19       Three

# %%
df.shape
# Out:
# (20, 4)

# %%
import numpy as np
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['Untitled Folder', 'pairarray', 'Untitled10.ipynb', 'Untitled7.ipynb', '.config', 'Weather_App(Python).ipynb', 'Music', 'HelloWorld', 'colours_css', '.zprofile.pysave', '.condarc', 'array addition', 'Untitled12.ipynb', 'Untitled5.ipynb', 'langchain_project', 'duparr', 'Untitled1.ipynb', 'swapfunc', 'CSS Media Queries', 'combinationfunc', '2Darray', 'maximumarray', 'loop array', '.DS_Store', 'CSS_StyleList', 'get-pip.py', 'arrmiss', '.CFUserTextEncoding', 'Pinterest', 'odd even array', 'CSS box model', '.xonshrc', 'JS Maps ', 'Project 2', 'CSS Grid', 'Untitled3.ipynb', 'CSS_Coloumns', 'langchain', 'Matplotlib_1.ipynb', 'Untitled14.ipynb', 'array', '.jssc', 'Untitled.ipynb', '.zshrc', 'sumarray', 'Task2done.ipynb', 'reccursion1', 'first', 'secondlargest.c', 'CSS Floats', 'Untitled4.ipynb', 'addmatrices', 'FrontEnd_Project', 'Untitled13.ipynb', 'CSS Images', 'Bar Plot.ipynb', 'Untitled6.ipynb', 'Pictures', 'Untitled11.ipynb', 'test.cpp', 'CSS_FLOATS', 'JS Function', 'arrayswap', 'countarray', '.zprofile', 'CSS_FLEXProject', 'LESSON_01', 'CSS_Position', 'node_modules', 'hello world', 'missing array', 'Histogram Plot.ipynb', 'untitled folder 2', 'Untitled15.ipynb', 'JS Switch', 'JS Console Objects', '.zsh_history', 'new.cpp', 'Untitled2.ipynb', '.ipython', 'Desktop', 'Library', 'callfunction', '.matplotlib', 'untitled folder 3', 'wave print', '.lesshst', 'JS Arrays', 'JS Project', 'libraryfunction', 'numberpattern', 'linear  search', 'Task 1.ipynb', 'array basics', 'bubble sort', 'CSS_List Style', 'access array', 'books.csv', 'PycharmProjects', 'Public', 'arraymarks', 'Task 3.ipynb', '2d ten elements array', 'package-lock.json', 'package.json', 'HTML Table', 'project2ok', '.idlerc', 'sortarr.c', '.tcshrc', 'cwh.html', 'bubbledsa', 'i:p array', '.anaconda', 'Untitled8.ipynb', 'evenoddsum array', '.ssh', 'Movies', 'Applications', 'JS For_Loops', 'WEB_Project', 'pythonoops', 'CSS_Typography', '.Trash', 'CSS_Flexbox', '.ipynb_checkpoints', 'langchainproject', 'CSS_StylingLinks', '.jupyter', '.keras', 'Pandas_df.ipynb', 'Mini Project', '.npm', 'transpose matrix', 'Documents', 'CSS_Units', 'indexcss.html', 'JS LearnWhat Matters', 'size of array', 'multiplication', '.mono', '.vscode', 'rotate 90 array', 'marksarray', '.bash_profile', 'anaconda3', 'Downloads', '.python_history', '.continuum', '.cache', 'Flex', '.gitconfig', 'Task 2', 'rotate array', 'Untitled9.ipynb', 'Untitled Folder 1', 'CSS_Display', '.bash_history', 'Exercise on JS', 'swapf.c', '.zsh_sessions', 'ccode', '2Darraymarks', 'CSS Mini_Project', '.conda', 'callmyfriends', 'Weather_App project.ipynb', 'maximumsumarr', 'JS ConditionalStatements']

# %%
df = pd.read_csv('books.csv')

# %%
df
# Out:
#     Unnamed: 0                                              Title  Price  \
# 0            0           The Nameless City (The Nameless City #1)  38.16
# 1            1  The Murder That Never Was (Forensic Instincts #5)  54.11
# 2            2  The Most Perfect Thing: Inside (and Outside) a...  42.96
# 3            3  The Mindfulness and Acceptance Workbook for An...  23.89
# 4            4  The Life-Changing Magic of Tidying Up: The Jap...  16.77
# 5            5  The Inefficiency Assassin: Time Management Tac...  20.59
# 6            6  The Gutsy Girl: Escapades for Your Life of Epi...  37.13
# 7            7  The Electric Pencil: Drawings from Inside Stat...  56.06
# 8            8       The Death of Humanity: and the Case for Life  58.11
# 9            9  The Bulletproof Diet: Lose up to a Pound a Day...  49.05
# 10          10                                     The Art Forger  40.76
# 11          11  The Age of Genius: The Seventeenth Century and...  19.73
# 12          12  The Activist's Tao Te Ching: Ancient Advice fo...  32.24
# 13          13  Spark Joy: An Illustrated Master Class on the ...  41.83
# 14          14                                        Soul Reader  39.58
# 15          15                                           Security  39.25
# 16          16      Saga, Volume 6 (Saga (Collected Editions) #6)  25.02
# 17          17      Saga, Volume 5 (Saga (Collected Editions) #5)  51.04
# 18          18  Reskilling America: Learning to Labor in the T...  19.83
# 19          19  Rat Queens, Vol. 3: Demons (Rat Queens (Collec...  50.40
#
#    Star Rating
# 0         Four
# 1        Three
# 2         Four
# 3         Four
# 4        Three
# 5         Five
# 6          One
# 7          One
# 8         Four
# 9        Three
# 10       Three
# 11         One
# 12        Five
# 13        Four
# 14         Two
# 15         Two
# 16       Three
# 17         Two
# 18         Two
# 19       Three

# %% [markdown]
# # Cleaning the data

# %%
df = pd.read_csv('books.csv', index_col=0,parse_dates=True)
df
# Out:
# /var/folders/vf/mgbms5c97jsfk65d3qczs72w0000gn/T/ipykernel_89405/461481397.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('books.csv', index_col=0,parse_dates=True)
#                                                 Title  Price Star Rating
# 0            The Nameless City (The Nameless City #1)  38.16        Four
# 1   The Murder That Never Was (Forensic Instincts #5)  54.11       Three
# 2   The Most Perfect Thing: Inside (and Outside) a...  42.96        Four
# 3   The Mindfulness and Acceptance Workbook for An...  23.89        Four
# 4   The Life-Changing Magic of Tidying Up: The Jap...  16.77       Three
# 5   The Inefficiency Assassin: Time Management Tac...  20.59        Five
# 6   The Gutsy Girl: Escapades for Your Life of Epi...  37.13         One
# 7   The Electric Pencil: Drawings from Inside Stat...  56.06         One
# 8        The Death of Humanity: and the Case for Life  58.11        Four
# 9   The Bulletproof Diet: Lose up to a Pound a Day...  49.05       Three
# 10                                     The Art Forger  40.76       Three
# 11  The Age of Genius: The Seventeenth Century and...  19.73         One
# 12  The Activist's Tao Te Ching: Ancient Advice fo...  32.24        Five
# 13  Spark Joy: An Illustrated Master Class on the ...  41.83        Four
# 14                                        Soul Reader  39.58         Two
# 15                                           Security  39.25         Two
# 16      Saga, Volume 6 (Saga (Collected Editions) #6)  25.02       Three
# 17      Saga, Volume 5 (Saga (Collected Editions) #5)  51.04         Two
# 18  Reskilling America: Learning to Labor in the T...  19.83         Two
# 19  Rat Queens, Vol. 3: Demons (Rat Queens (Collec...  50.40       Three

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
df.dropna()
# Out:
#                                                 Title  Price Star Rating
# 0            The Nameless City (The Nameless City #1)  38.16        Four
# 1   The Murder That Never Was (Forensic Instincts #5)  54.11       Three
# 2   The Most Perfect Thing: Inside (and Outside) a...  42.96        Four
# 3   The Mindfulness and Acceptance Workbook for An...  23.89        Four
# 4   The Life-Changing Magic of Tidying Up: The Jap...  16.77       Three
# 5   The Inefficiency Assassin: Time Management Tac...  20.59        Five
# 6   The Gutsy Girl: Escapades for Your Life of Epi...  37.13         One
# 7   The Electric Pencil: Drawings from Inside Stat...  56.06         One
# 8        The Death of Humanity: and the Case for Life  58.11        Four
# 9   The Bulletproof Diet: Lose up to a Pound a Day...  49.05       Three
# 10                                     The Art Forger  40.76       Three
# 11  The Age of Genius: The Seventeenth Century and...  19.73         One
# 12  The Activist's Tao Te Ching: Ancient Advice fo...  32.24        Five
# 13  Spark Joy: An Illustrated Master Class on the ...  41.83        Four
# 14                                        Soul Reader  39.58         Two
# 15                                           Security  39.25         Two
# 16      Saga, Volume 6 (Saga (Collected Editions) #6)  25.02       Three
# 17      Saga, Volume 5 (Saga (Collected Editions) #5)  51.04         Two
# 18  Reskilling America: Learning to Labor in the T...  19.83         Two
# 19  Rat Queens, Vol. 3: Demons (Rat Queens (Collec...  50.40       Three

# %%
# SO MY DATA IS CORRECT TOTALLY
