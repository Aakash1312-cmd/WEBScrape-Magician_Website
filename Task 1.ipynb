# %%
import requests
from bs4 import BeautifulSoup

url = "https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/delivery/"
r = requests.get(url)
# print(r)



soup = BeautifulSoup(r.text, "lxml")

# print(soup)

menu = soup.find_all("article",class_= "itemInfo")

# print(len(menu_price))// Fetching the length of the price and menu boxes

for i in menu:
    print(i.text)
    
    
    
    
# To scrap the popular menu and its price 
# url1="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/menu/"
# r = requests.get(url1)



# soup_all = BeautifulSoup(r.text, "lxml")

# popular_menu_price = soup_all.find_all("div",class_ = "item-container")



# for k in popular_menu_price:
#     print(k.text)

# %%
# To get the price of the food items seperately

url = "https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/delivery/"
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")


price = soup.find_all("span",class_ = "itemPrice")


for i in price:
    print(i.text)
# Out:
#  ₹249
#  ₹239
#  ₹308
#  ₹199
#  ₹319
#  ₹280
#  ₹260
#  ₹330
#  ₹288
#  ₹319
#  ₹348
#  ₹308
#  ₹259
#  ₹229
#  ₹239
#  ₹268
#  ₹259
#  ₹229
#  ₹268
#  ₹239
#  ₹258
#  ₹228
#  ₹267
#  ₹268
#  ₹288
#  ₹288
#  ₹279
#  ₹279
#  ₹288
#  ₹288
#  ₹287
#  ₹229
#  ₹229
#  ₹219
#  ₹218
#  ₹399
#  ₹398
#  ₹407
#  ₹318
#  ₹307
#  ₹278
#  ₹327
#  ₹318
#  ₹258
#  ₹327
#  ₹338
#  ₹338
#  ₹347
#  ₹228
#  ₹268
#  ₹279
#  ₹259
#  ₹277
#  ₹279
#  ₹297
#  ₹298
#  ₹259
#  ₹249
#  ₹297
#  ₹319
#  ₹299
#  ₹287
#  ₹249
#  ₹347
#  ₹288
#  ₹139
#  ₹219
#  ₹59
#  ₹69
#  ₹59
#  ₹199
#  ₹180
#  ₹79
#  ₹68
#  ₹149
#  ₹228
#  ₹328
#  ₹299
#  ₹278
#  ₹329
#  ₹308
#  ₹339
#  ₹348
#  ₹79
#  ₹99
#  ₹139
#  ₹99
#  ₹89
#  ₹79
#  ₹399
#  ₹153
#  ₹89
#  ₹79
#  ₹79
#  ₹59
#  ₹139
#  ₹62
#  ₹99
#  ₹69
#  ₹89
#  ₹89
#  ₹75
#  ₹62
#  ₹107
#  ₹107
